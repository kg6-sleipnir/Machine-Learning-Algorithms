# %% [markdown]
# # Neural Net Using Pytorch
# This model uses Pytorch to create a multi-layered neural network with a sigmoid activation function.

# %% [markdown]
# ### Neural Net Definition

# %%
from torch import nn, optim, Tensor

#
# Neural network for learning boolean operations
#
class NeuralNet(nn.Module):
    def __init__(self) -> None:
        """Init NeuralNet with 2 inputs, 1 hidden layer with 4 nodes, and 2 outputs"""
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(2, 4),
            nn.Sigmoid(),
            nn.Linear(4, 2)
        )

    def forward(self, x) -> Tensor:
        """Propagate values through layer in network"""
        logits = self.layers(x)
        probs = nn.Softmax(0)(logits)
        return probs

# %%
_model = NeuralNet()
print(_model)
# Out:
# NeuralNet(
#   (layers): Sequential(
#     (0): Linear(in_features=2, out_features=4, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=4, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### Util Class for Boolean Operations Dataset

# %%
import numpy as np
import operator

def get_pair(operator) -> tuple[Tensor, int]:
    """Generate a set of inputs and correct output for model"""
    values = np.random.choice([1, 0], 2)            # Two random inputs
    answer = [int(operator(values[0], values[1]))]  # Get correct output
    answer += [int(not answer[0])]
    return Tensor(values), Tensor(answer)

# %% [markdown]
# ### Util Functions for Training/Validating

# %%
loss_fn = nn.MSELoss()
optimizer = optim.SGD(_model.parameters(),lr=0.009)

def train(operator, batches, model=_model) -> None:
    for batch in range(batches):
        data, label = get_pair(operator)
        pred = model(data)
        loss = loss_fn(pred, label)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

# %%
def validate(operator, model=_model) -> None:
    """Validate the test neural network"""
    # Generate validation set
    values: list[list[int]] = []
    for val_1 in range(2):
        for val_2 in range(2):
            values.append([val_1, val_2])

    # Run network on validation set
    for it, inputs in enumerate(values):
        pred = model(Tensor(inputs))
        label = [int(operator(inputs[0], inputs[1]))]
        label += [int(not label[0])]
        print(f"Validation: {it:3}\n"
              f"  Input: {inputs}\n"
              f"  Pred: [{pred[0]:.6f}, {pred[1]:.6f}]\n"
              f"  label: {label}\n"
              f"  loss: {loss_fn(Tensor(pred), Tensor(label))}")

# %% [markdown]
# ### Train and Evaluate Model

# %%
op = operator.and_
epochs = 200
for epoch in range(epochs):
    print(f"Epoch {epoch+1:02d} " + "="*30)
    train(op, 100)
    validate(op)
    print("="*40)
# Out:
# Epoch 01 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.230003, 0.769997]
#   label: [0, 1]
#   loss: 0.05290120095014572
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.238125, 0.761875]
#   label: [0, 1]
#   loss: 0.05670361593365669
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.294322, 0.705678]
#   label: [0, 1]
#   loss: 0.08662537485361099
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.304485, 0.695515]
#   label: [1, 0]
#   loss: 0.4837416410446167
# ========================================
# Epoch 02 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.244403, 0.755597]
#   label: [0, 1]
#   loss: 0.05973271280527115
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.254284, 0.745716]
#   label: [0, 1]
#   loss: 0.06466048955917358
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.312730, 0.687270]
#   label: [0, 1]
#   loss: 0.09780015051364899
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.324787, 0.675213]
#   label: [1, 0]
#   loss: 0.4559127390384674
# ========================================
# Epoch 03 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.232771, 0.767229]
#   label: [0, 1]
#   loss: 0.054182473570108414
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.243553, 0.756447]
#   label: [0, 1]
#   loss: 0.05931811407208443
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.301620, 0.698380]
#   label: [0, 1]
#   loss: 0.09097468852996826
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.314830, 0.685170]
#   label: [1, 0]
#   loss: 0.46945804357528687
# ========================================
# Epoch 04 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.228419, 0.771581]
#   label: [0, 1]
#   loss: 0.05217505991458893
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.240302, 0.759698]
#   label: [0, 1]
#   loss: 0.0577450655400753
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.298715, 0.701285]
#   label: [0, 1]
#   loss: 0.08923088014125824
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.313250, 0.686750]
#   label: [1, 0]
#   loss: 0.4716256260871887
# ========================================
# Epoch 05 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.209944, 0.790056]
#   label: [0, 1]
#   loss: 0.044076431542634964
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.222332, 0.777668]
#   label: [0, 1]
#   loss: 0.049431417137384415
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.278857, 0.721143]
#   label: [0, 1]
#   loss: 0.07776105403900146
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.294223, 0.705777]
#   label: [1, 0]
#   loss: 0.4981207251548767
# ========================================
# Epoch 06 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.238523, 0.761477]
#   label: [0, 1]
#   loss: 0.0568930059671402
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.253384, 0.746616]
#   label: [0, 1]
#   loss: 0.06420347094535828
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.314686, 0.685314]
#   label: [0, 1]
#   loss: 0.09902709722518921
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.332483, 0.667517]
#   label: [1, 0]
#   loss: 0.44557854533195496
# ========================================
# Epoch 07 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.234036, 0.765964]
#   label: [0, 1]
#   loss: 0.054772842675447464
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.250167, 0.749833]
#   label: [0, 1]
#   loss: 0.06258375197649002
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.311733, 0.688267]
#   label: [0, 1]
#   loss: 0.0971771627664566
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.331051, 0.668949]
#   label: [1, 0]
#   loss: 0.4474928677082062
# ========================================
# Epoch 08 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.218177, 0.781823]
#   label: [0, 1]
#   loss: 0.047601088881492615
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.234891, 0.765109]
#   label: [0, 1]
#   loss: 0.05517369881272316
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.295199, 0.704801]
#   label: [0, 1]
#   loss: 0.08714231848716736
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.315504, 0.684496]
#   label: [1, 0]
#   loss: 0.46853429079055786
# ========================================
# Epoch 09 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.233515, 0.766485]
#   label: [0, 1]
#   loss: 0.05452945828437805
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.252326, 0.747674]
#   label: [0, 1]
#   loss: 0.06366855651140213
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.315903, 0.684097]
#   label: [0, 1]
#   loss: 0.09979449212551117
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.338283, 0.661717]
#   label: [1, 0]
#   loss: 0.4378700256347656
# ========================================
# Epoch 10 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.233294, 0.766706]
#   label: [0, 1]
#   loss: 0.05442631617188454
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.253663, 0.746337]
#   label: [0, 1]
#   loss: 0.0643448457121849
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.318023, 0.681977]
#   label: [0, 1]
#   loss: 0.10113877803087234
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.342164, 0.657836]
#   label: [1, 0]
#   loss: 0.43274879455566406
# ========================================
# Epoch 11 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.226144, 0.773856]
#   label: [0, 1]
#   loss: 0.05114110931754112
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.247772, 0.752228]
#   label: [0, 1]
#   loss: 0.06139114126563072
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.311869, 0.688131]
#   label: [0, 1]
#   loss: 0.09726229310035706
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.337622, 0.662378]
#   label: [1, 0]
#   loss: 0.43874478340148926
# ========================================
# Epoch 12 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.225095, 0.774905]
#   label: [0, 1]
#   loss: 0.05066768825054169
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.248566, 0.751434]
#   label: [0, 1]
#   loss: 0.061785198748111725
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.313161, 0.686839]
#   label: [0, 1]
#   loss: 0.0980699211359024
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.341018, 0.658982]
#   label: [1, 0]
#   loss: 0.43425747752189636
# ========================================
# Epoch 13 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.210570, 0.789430]
#   label: [0, 1]
#   loss: 0.04433991014957428
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.234694, 0.765306]
#   label: [0, 1]
#   loss: 0.055081166326999664
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.298086, 0.701914]
#   label: [0, 1]
#   loss: 0.08885513246059418
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.327183, 0.672817]
#   label: [1, 0]
#   loss: 0.4526820480823517
# ========================================
# Epoch 14 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.207748, 0.792252]
#   label: [0, 1]
#   loss: 0.04315931349992752
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.233406, 0.766594]
#   label: [0, 1]
#   loss: 0.05447820574045181
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.297005, 0.702995]
#   label: [0, 1]
#   loss: 0.08821182698011398
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.327969, 0.672031]
#   label: [1, 0]
#   loss: 0.4516255259513855
# ========================================
# Epoch 15 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.204786, 0.795214]
#   label: [0, 1]
#   loss: 0.041937150061130524
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.231711, 0.768289]
#   label: [0, 1]
#   loss: 0.0536898635327816
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.295887, 0.704113]
#   label: [0, 1]
#   loss: 0.08754932135343552
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.328454, 0.671546]
#   label: [1, 0]
#   loss: 0.45097416639328003
# ========================================
# Epoch 16 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.202350, 0.797650]
#   label: [0, 1]
#   loss: 0.040945470333099365
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.230803, 0.769197]
#   label: [0, 1]
#   loss: 0.05326998233795166
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.295197, 0.704803]
#   label: [0, 1]
#   loss: 0.08714152872562408
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.329634, 0.670366]
#   label: [1, 0]
#   loss: 0.4493906497955322
# ========================================
# Epoch 17 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.198509, 0.801491]
#   label: [0, 1]
#   loss: 0.03940577059984207
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.228293, 0.771707]
#   label: [0, 1]
#   loss: 0.05211765319108963
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.292648, 0.707352]
#   label: [0, 1]
#   loss: 0.08564282953739166
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.328810, 0.671190]
#   label: [1, 0]
#   loss: 0.4504961669445038
# ========================================
# Epoch 18 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.199910, 0.800090]
#   label: [0, 1]
#   loss: 0.03996393084526062
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.231681, 0.768319]
#   label: [0, 1]
#   loss: 0.05367612466216087
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.296802, 0.703198]
#   label: [0, 1]
#   loss: 0.08809138089418411
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.335182, 0.664818]
#   label: [1, 0]
#   loss: 0.4419827163219452
# ========================================
# Epoch 19 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.217051, 0.782948]
#   label: [0, 1]
#   loss: 0.047111354768276215
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.252941, 0.747059]
#   label: [0, 1]
#   loss: 0.06397922337055206
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.321393, 0.678607]
#   label: [0, 1]
#   loss: 0.10329332947731018
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.363427, 0.636573]
#   label: [1, 0]
#   loss: 0.40522557497024536
# ========================================
# Epoch 20 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.222019, 0.777981]
#   label: [0, 1]
#   loss: 0.04929230734705925
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.260524, 0.739476]
#   label: [0, 1]
#   loss: 0.06787290424108505
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.330834, 0.669166]
#   label: [0, 1]
#   loss: 0.10945124924182892
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.375440, 0.624560]
#   label: [1, 0]
#   loss: 0.3900751769542694
# ========================================
# Epoch 21 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.227576, 0.772424]
#   label: [0, 1]
#   loss: 0.05179093778133392
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.269187, 0.730813]
#   label: [0, 1]
#   loss: 0.07246176153421402
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.341182, 0.658818]
#   label: [0, 1]
#   loss: 0.11640520393848419
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.388758, 0.611242]
#   label: [1, 0]
#   loss: 0.3736168444156647
# ========================================
# Epoch 22 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.229763, 0.770237]
#   label: [0, 1]
#   loss: 0.05279119312763214
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.274038, 0.725962]
#   label: [0, 1]
#   loss: 0.07509668171405792
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.347929, 0.652071]
#   label: [0, 1]
#   loss: 0.12105470895767212
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.398181, 0.601819]
#   label: [1, 0]
#   loss: 0.36218634247779846
# ========================================
# Epoch 23 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.224508, 0.775492]
#   label: [0, 1]
#   loss: 0.0504036471247673
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.270572, 0.729428]
#   label: [0, 1]
#   loss: 0.07320897281169891
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.345225, 0.654775]
#   label: [0, 1]
#   loss: 0.11918028444051743
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.397788, 0.602212]
#   label: [1, 0]
#   loss: 0.36265894770622253
# ========================================
# Epoch 24 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.213392, 0.786608]
#   label: [0, 1]
#   loss: 0.04553620517253876
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.260665, 0.739335]
#   label: [0, 1]
#   loss: 0.06794621795415878
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.334587, 0.665413]
#   label: [0, 1]
#   loss: 0.11194849014282227
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.389380, 0.610620]
#   label: [1, 0]
#   loss: 0.37285640835762024
# ========================================
# Epoch 25 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.214721, 0.785279]
#   label: [0, 1]
#   loss: 0.04610513150691986
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.264978, 0.735022]
#   label: [0, 1]
#   loss: 0.0702134519815445
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.339843, 0.660157]
#   label: [0, 1]
#   loss: 0.11549315601587296
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.397703, 0.602297]
#   label: [1, 0]
#   loss: 0.36276182532310486
# ========================================
# Epoch 26 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.187730, 0.812270]
#   label: [0, 1]
#   loss: 0.0352424681186676
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.235704, 0.764296]
#   label: [0, 1]
#   loss: 0.05555624142289162
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.307171, 0.692829]
#   label: [0, 1]
#   loss: 0.09435372054576874
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.365240, 0.634760]
#   label: [1, 0]
#   loss: 0.40292030572891235
# ========================================
# Epoch 27 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.191174, 0.808826]
#   label: [0, 1]
#   loss: 0.036547403782606125
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.242404, 0.757596]
#   label: [0, 1]
#   loss: 0.05875978246331215
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.314844, 0.685156]
#   label: [0, 1]
#   loss: 0.09912696480751038
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.376206, 0.623794]
#   label: [1, 0]
#   loss: 0.3891194462776184
# ========================================
# Epoch 28 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.173503, 0.826497]
#   label: [0, 1]
#   loss: 0.030103154480457306
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.223440, 0.776560]
#   label: [0, 1]
#   loss: 0.0499253012239933
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.292951, 0.707049]
#   label: [0, 1]
#   loss: 0.0858205109834671
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.354900, 0.645100]
#   label: [1, 0]
#   loss: 0.41615456342697144
# ========================================
# Epoch 29 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.167581, 0.832418]
#   label: [0, 1]
#   loss: 0.028083568438887596
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.218691, 0.781309]
#   label: [0, 1]
#   loss: 0.04782583564519882
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.286986, 0.713014]
#   label: [0, 1]
#   loss: 0.08236096799373627
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.351029, 0.648971]
#   label: [1, 0]
#   loss: 0.42116373777389526
# ========================================
# Epoch 30 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.157779, 0.842220]
#   label: [0, 1]
#   loss: 0.024894367903470993
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.208517, 0.791483]
#   label: [0, 1]
#   loss: 0.043479450047016144
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.275257, 0.724743]
#   label: [0, 1]
#   loss: 0.07576651871204376
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.340194, 0.659806]
#   label: [1, 0]
#   loss: 0.43534356355667114
# ========================================
# Epoch 31 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.168823, 0.831177]
#   label: [0, 1]
#   loss: 0.02850119024515152
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.224607, 0.775393]
#   label: [0, 1]
#   loss: 0.05044851824641228
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.294537, 0.705463]
#   label: [0, 1]
#   loss: 0.08675180375576019
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.363942, 0.636058]
#   label: [1, 0]
#   loss: 0.40456947684288025
# ========================================
# Epoch 32 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.150743, 0.849257]
#   label: [0, 1]
#   loss: 0.022723488509655
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.204123, 0.795877]
#   label: [0, 1]
#   loss: 0.04166615754365921
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.269943, 0.730057]
#   label: [0, 1]
#   loss: 0.07286900281906128
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.339167, 0.660833]
#   label: [1, 0]
#   loss: 0.43670040369033813
# ========================================
# Epoch 33 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.148006, 0.851994]
#   label: [0, 1]
#   loss: 0.021905891597270966
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.202808, 0.797192]
#   label: [0, 1]
#   loss: 0.041130952537059784
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.268073, 0.731927]
#   label: [0, 1]
#   loss: 0.07186323404312134
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.339487, 0.660513]
#   label: [1, 0]
#   loss: 0.43627750873565674
# ========================================
# Epoch 34 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.151343, 0.848657]
#   label: [0, 1]
#   loss: 0.022904623299837112
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.209271, 0.790729]
#   label: [0, 1]
#   loss: 0.043794188648462296
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.275755, 0.724245]
#   label: [0, 1]
#   loss: 0.07604097574949265
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.350465, 0.649535]
#   label: [1, 0]
#   loss: 0.4218961000442505
# ========================================
# Epoch 35 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.157080, 0.842920]
#   label: [0, 1]
#   loss: 0.024674035608768463
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.218829, 0.781171]
#   label: [0, 1]
#   loss: 0.0478862002491951
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.287809, 0.712191]
#   label: [0, 1]
#   loss: 0.08283412456512451
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.366171, 0.633829]
#   label: [1, 0]
#   loss: 0.40173959732055664
# ========================================
# Epoch 36 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.153280, 0.846720]
#   label: [0, 1]
#   loss: 0.023494750261306763
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.216171, 0.783829]
#   label: [0, 1]
#   loss: 0.046730078756809235
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.284999, 0.715001]
#   label: [0, 1]
#   loss: 0.08122454583644867
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.365476, 0.634524]
#   label: [1, 0]
#   loss: 0.40262100100517273
# ========================================
# Epoch 37 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.156613, 0.843387]
#   label: [0, 1]
#   loss: 0.02452775277197361
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.223055, 0.776945]
#   label: [0, 1]
#   loss: 0.04975363612174988
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.293181, 0.706819]
#   label: [0, 1]
#   loss: 0.08595503121614456
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.377250, 0.622750]
#   label: [1, 0]
#   loss: 0.38781803846359253
# ========================================
# Epoch 38 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.162910, 0.837090]
#   label: [0, 1]
#   loss: 0.02653980255126953
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.234032, 0.765968]
#   label: [0, 1]
#   loss: 0.05477091297507286
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.306339, 0.693661]
#   label: [0, 1]
#   loss: 0.09384380280971527
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.394586, 0.605414]
#   label: [1, 0]
#   loss: 0.36652615666389465
# ========================================
# Epoch 39 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.171331, 0.828669]
#   label: [0, 1]
#   loss: 0.02935447357594967
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.247911, 0.752089]
#   label: [0, 1]
#   loss: 0.061459869146347046
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.323305, 0.676695]
#   label: [0, 1]
#   loss: 0.10452643781900406
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.415919, 0.584081]
#   label: [1, 0]
#   loss: 0.3411506712436676
# ========================================
# Epoch 40 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.177575, 0.822425]
#   label: [0, 1]
#   loss: 0.031532805413007736
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.259268, 0.740732]
#   label: [0, 1]
#   loss: 0.067220039665699
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.336924, 0.663076]
#   label: [0, 1]
#   loss: 0.11351790279150009
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.433709, 0.566291]
#   label: [1, 0]
#   loss: 0.320686012506485
# ========================================
# Epoch 41 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.166392, 0.833608]
#   label: [0, 1]
#   loss: 0.027686309069395065
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.247206, 0.752794]
#   label: [0, 1]
#   loss: 0.06111086159944534
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.323868, 0.676132]
#   label: [0, 1]
#   loss: 0.10489049553871155
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.422392, 0.577608]
#   label: [1, 0]
#   loss: 0.3336310386657715
# ========================================
# Epoch 42 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.176819, 0.823181]
#   label: [0, 1]
#   loss: 0.03126492351293564
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.264926, 0.735074]
#   label: [0, 1]
#   loss: 0.07018567621707916
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.344180, 0.655820]
#   label: [0, 1]
#   loss: 0.11845956742763519
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.447919, 0.552081]
#   label: [1, 0]
#   loss: 0.3047938942909241
# ========================================
# Epoch 43 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.158990, 0.841010]
#   label: [0, 1]
#   loss: 0.025277793407440186
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.243932, 0.756068]
#   label: [0, 1]
#   loss: 0.05950301140546799
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.319978, 0.680022]
#   label: [0, 1]
#   loss: 0.10238607972860336
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.425058, 0.574942]
#   label: [1, 0]
#   loss: 0.330558717250824
# ========================================
# Epoch 44 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.143626, 0.856374]
#   label: [0, 1]
#   loss: 0.02062833495438099
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.225044, 0.774956]
#   label: [0, 1]
#   loss: 0.05064485967159271
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.298136, 0.701864]
#   label: [0, 1]
#   loss: 0.08888500183820724
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.403678, 0.596322]
#   label: [1, 0]
#   loss: 0.35559993982315063
# ========================================
# Epoch 45 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.154726, 0.845274]
#   label: [0, 1]
#   loss: 0.023940037935972214
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.244496, 0.755504]
#   label: [0, 1]
#   loss: 0.059778470546007156
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.320489, 0.679511]
#   label: [0, 1]
#   loss: 0.10271292179822922
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.432278, 0.567722]
#   label: [1, 0]
#   loss: 0.32230862975120544
# ========================================
# Epoch 46 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.151970, 0.848030]
#   label: [0, 1]
#   loss: 0.023094862699508667
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.243757, 0.756243]
#   label: [0, 1]
#   loss: 0.05941738933324814
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.319953, 0.680047]
#   label: [0, 1]
#   loss: 0.10236962139606476
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.434914, 0.565086]
#   label: [1, 0]
#   loss: 0.31932178139686584
# ========================================
# Epoch 47 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.153860, 0.846140]
#   label: [0, 1]
#   loss: 0.023672979325056076
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.249806, 0.750194]
#   label: [0, 1]
#   loss: 0.06240323185920715
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.327402, 0.672598]
#   label: [0, 1]
#   loss: 0.10719217360019684
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.446350, 0.553650]
#   label: [1, 0]
#   loss: 0.30652791261672974
# ========================================
# Epoch 48 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.145363, 0.854637]
#   label: [0, 1]
#   loss: 0.021130405366420746
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.240673, 0.759327]
#   label: [0, 1]
#   loss: 0.05792350322008133
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.316736, 0.683264]
#   label: [0, 1]
#   loss: 0.10032164305448532
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.438029, 0.561971]
#   label: [1, 0]
#   loss: 0.31581106781959534
# ========================================
# Epoch 49 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.148658, 0.851342]
#   label: [0, 1]
#   loss: 0.022099286317825317
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.248904, 0.751096]
#   label: [0, 1]
#   loss: 0.061953213065862656
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.326999, 0.673001]
#   label: [0, 1]
#   loss: 0.10692866146564484
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.452647, 0.547353]
#   label: [1, 0]
#   loss: 0.2995949387550354
# ========================================
# Epoch 50 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.144533, 0.855467]
#   label: [0, 1]
#   loss: 0.02088974416255951
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.246027, 0.753973]
#   label: [0, 1]
#   loss: 0.060529377311468124
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.324198, 0.675802]
#   label: [0, 1]
#   loss: 0.1051044762134552
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.452921, 0.547079]
#   label: [1, 0]
#   loss: 0.29929572343826294
# ========================================
# Epoch 51 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.138953, 0.861047]
#   label: [0, 1]
#   loss: 0.019308000802993774
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.240750, 0.759250]
#   label: [0, 1]
#   loss: 0.057960525155067444
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.318329, 0.681671]
#   label: [0, 1]
#   loss: 0.10133355855941772
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.449781, 0.550219]
#   label: [1, 0]
#   loss: 0.3027408719062805
# ========================================
# Epoch 52 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.132492, 0.867508]
#   label: [0, 1]
#   loss: 0.017554087564349174
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.234111, 0.765889]
#   label: [0, 1]
#   loss: 0.05480814352631569
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.310425, 0.689575]
#   label: [0, 1]
#   loss: 0.09636369347572327
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.444595, 0.555405]
#   label: [1, 0]
#   loss: 0.3084748685359955
# ========================================
# Epoch 53 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.142401, 0.857599]
#   label: [0, 1]
#   loss: 0.020277971401810646
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.253511, 0.746489]
#   label: [0, 1]
#   loss: 0.06426779180765152
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.333342, 0.666658]
#   label: [0, 1]
#   loss: 0.1111169159412384
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.473723, 0.526277]
#   label: [1, 0]
#   loss: 0.27696794271469116
# ========================================
# Epoch 54 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.133372, 0.866628]
#   label: [0, 1]
#   loss: 0.017788143828511238
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.242623, 0.757377]
#   label: [0, 1]
#   loss: 0.058865971863269806
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.320878, 0.679122]
#   label: [0, 1]
#   loss: 0.1029626801609993
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.463561, 0.536439]
#   label: [1, 0]
#   loss: 0.2877669334411621
# ========================================
# Epoch 55 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.120747, 0.879253]
#   label: [0, 1]
#   loss: 0.014579851180315018
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.224711, 0.775289]
#   label: [0, 1]
#   loss: 0.050495125353336334
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.300557, 0.699443]
#   label: [0, 1]
#   loss: 0.09033423662185669
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.443695, 0.556305]
#   label: [1, 0]
#   loss: 0.30947503447532654
# ========================================
# Epoch 56 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.116700, 0.883300]
#   label: [0, 1]
#   loss: 0.013618826866149902
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.220582, 0.779418]
#   label: [0, 1]
#   loss: 0.04865644872188568
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.296282, 0.703718]
#   label: [0, 1]
#   loss: 0.08778323233127594
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.441648, 0.558352]
#   label: [1, 0]
#   loss: 0.31175652146339417
# ========================================
# Epoch 57 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.125230, 0.874770]
#   label: [0, 1]
#   loss: 0.01568247564136982
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.238970, 0.761030]
#   label: [0, 1]
#   loss: 0.057106729596853256
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.317493, 0.682507]
#   label: [0, 1]
#   loss: 0.10080204904079437
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.469836, 0.530164]
#   label: [1, 0]
#   loss: 0.28107374906539917
# ========================================
# Epoch 58 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.124834, 0.875166]
#   label: [0, 1]
#   loss: 0.015583437867462635
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.241656, 0.758344]
#   label: [0, 1]
#   loss: 0.05839746445417404
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.321139, 0.678861]
#   label: [0, 1]
#   loss: 0.10313024371862411
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.477306, 0.522694]
#   label: [1, 0]
#   loss: 0.27320945262908936
# ========================================
# Epoch 59 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.119366, 0.880634]
#   label: [0, 1]
#   loss: 0.014248156920075417
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.235651, 0.764349]
#   label: [0, 1]
#   loss: 0.055531445890665054
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.314211, 0.685789]
#   label: [0, 1]
#   loss: 0.09872841089963913
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.473197, 0.526803]
#   label: [1, 0]
#   loss: 0.27752190828323364
# ========================================
# Epoch 60 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.112499, 0.887501]
#   label: [0, 1]
#   loss: 0.012655945494771004
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.226526, 0.773474]
#   label: [0, 1]
#   loss: 0.05131398141384125
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.303793, 0.696207]
#   label: [0, 1]
#   loss: 0.09229040890932083
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.464645, 0.535355]
#   label: [1, 0]
#   loss: 0.2866053283214569
# ========================================
# Epoch 61 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.117827, 0.882173]
#   label: [0, 1]
#   loss: 0.013883151113986969
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.239828, 0.760172]
#   label: [0, 1]
#   loss: 0.05751731991767883
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.319667, 0.680332]
#   label: [0, 1]
#   loss: 0.10218731313943863
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.486440, 0.513560]
#   label: [1, 0]
#   loss: 0.2637438476085663
# ========================================
# Epoch 62 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.105931, 0.894069]
#   label: [0, 1]
#   loss: 0.01122144516557455
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.221076, 0.778924]
#   label: [0, 1]
#   loss: 0.048874493688344955
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.297949, 0.702051]
#   label: [0, 1]
#   loss: 0.08877362310886383
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.465167, 0.534833]
#   label: [1, 0]
#   loss: 0.2860462963581085
# ========================================
# Epoch 63 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.116265, 0.883735]
#   label: [0, 1]
#   loss: 0.013517661951482296
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.244635, 0.755365]
#   label: [0, 1]
#   loss: 0.059846069663763046
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.324557, 0.675443]
#   label: [0, 1]
#   loss: 0.10533743351697922
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.499781, 0.500219]
#   label: [1, 0]
#   loss: 0.2502191662788391
# ========================================
# Epoch 64 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.113080, 0.886920]
#   label: [0, 1]
#   loss: 0.012787091545760632
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.242604, 0.757396]
#   label: [0, 1]
#   loss: 0.0588565394282341
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.321954, 0.678046]
#   label: [0, 1]
#   loss: 0.10365423560142517
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.500941, 0.499059]
#   label: [1, 0]
#   loss: 0.2490595281124115
# ========================================
# Epoch 65 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.107835, 0.892165]
#   label: [0, 1]
#   loss: 0.011628331616520882
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.236306, 0.763694]
#   label: [0, 1]
#   loss: 0.05584059655666351
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.314416, 0.685584]
#   label: [0, 1]
#   loss: 0.0988573431968689
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.496459, 0.503541]
#   label: [1, 0]
#   loss: 0.2535531520843506
# ========================================
# Epoch 66 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.107159, 0.892841]
#   label: [0, 1]
#   loss: 0.011483080685138702
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.238878, 0.761122]
#   label: [0, 1]
#   loss: 0.05706282705068588
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.316926, 0.683074]
#   label: [0, 1]
#   loss: 0.10044229030609131
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.503360, 0.496640]
#   label: [1, 0]
#   loss: 0.246651291847229
# ========================================
# Epoch 67 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.107520, 0.892480]
#   label: [0, 1]
#   loss: 0.011560522951185703
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.244247, 0.755753]
#   label: [0, 1]
#   loss: 0.05965648591518402
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.321662, 0.678338]
#   label: [0, 1]
#   loss: 0.10346636176109314
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.513555, 0.486445]
#   label: [1, 0]
#   loss: 0.236628457903862
# ========================================
# Epoch 68 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.100900, 0.899100]
#   label: [0, 1]
#   loss: 0.010180856101214886
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.234551, 0.765449]
#   label: [0, 1]
#   loss: 0.05501416325569153
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.310249, 0.689751]
#   label: [0, 1]
#   loss: 0.09625428915023804
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.504674, 0.495326]
#   label: [1, 0]
#   loss: 0.24534766376018524
# ========================================
# Epoch 69 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.098724, 0.901276]
#   label: [0, 1]
#   loss: 0.009746457450091839
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.233907, 0.766093]
#   label: [0, 1]
#   loss: 0.05471264198422432
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.309339, 0.690661]
#   label: [0, 1]
#   loss: 0.09569084644317627
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.507805, 0.492195]
#   label: [1, 0]
#   loss: 0.24225559830665588
# ========================================
# Epoch 70 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.095578, 0.904422]
#   label: [0, 1]
#   loss: 0.009135175496339798
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.230633, 0.769367]
#   label: [0, 1]
#   loss: 0.05319143086671829
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.306175, 0.693825]
#   label: [0, 1]
#   loss: 0.09374311566352844
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.507838, 0.492162]
#   label: [1, 0]
#   loss: 0.24222354590892792
# ========================================
# Epoch 71 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.095335, 0.904665]
#   label: [0, 1]
#   loss: 0.009088747203350067
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.234645, 0.765355]
#   label: [0, 1]
#   loss: 0.055058129131793976
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.309549, 0.690451]
#   label: [0, 1]
#   loss: 0.09582079946994781
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.516651, 0.483349]
#   label: [1, 0]
#   loss: 0.23362627625465393
# ========================================
# Epoch 72 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.086307, 0.913693]
#   label: [0, 1]
#   loss: 0.00744891632348299
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.218973, 0.781027]
#   label: [0, 1]
#   loss: 0.04794929176568985
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.289321, 0.710679]
#   label: [0, 1]
#   loss: 0.08370658755302429
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.498340, 0.501660]
#   label: [1, 0]
#   loss: 0.2516624927520752
# ========================================
# Epoch 73 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.086527, 0.913473]
#   label: [0, 1]
#   loss: 0.00748697342351079
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.223346, 0.776654]
#   label: [0, 1]
#   loss: 0.0498834103345871
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.293492, 0.706508]
#   label: [0, 1]
#   loss: 0.08613762259483337
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.507574, 0.492426]
#   label: [1, 0]
#   loss: 0.24248337745666504
# ========================================
# Epoch 74 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.081465, 0.918535]
#   label: [0, 1]
#   loss: 0.006636613514274359
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.215550, 0.784450]
#   label: [0, 1]
#   loss: 0.046461768448352814
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.283346, 0.716654]
#   label: [0, 1]
#   loss: 0.08028478175401688
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.500328, 0.499672]
#   label: [1, 0]
#   loss: 0.24967190623283386
# ========================================
# Epoch 75 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.080413, 0.919587]
#   label: [0, 1]
#   loss: 0.006466316059231758
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.217038, 0.782962]
#   label: [0, 1]
#   loss: 0.04710545763373375
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.283484, 0.716516]
#   label: [0, 1]
#   loss: 0.08036298304796219
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.505130, 0.494870]
#   label: [1, 0]
#   loss: 0.2448967844247818
# ========================================
# Epoch 76 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.078951, 0.921049]
#   label: [0, 1]
#   loss: 0.00623320322483778
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.217020, 0.782980]
#   label: [0, 1]
#   loss: 0.047097884118556976
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.282787, 0.717213]
#   label: [0, 1]
#   loss: 0.07996857911348343
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.508361, 0.491639]
#   label: [1, 0]
#   loss: 0.24170932173728943
# ========================================
# Epoch 77 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.077716, 0.922284]
#   label: [0, 1]
#   loss: 0.006039840169250965
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.217250, 0.782750]
#   label: [0, 1]
#   loss: 0.04719743877649307
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.282975, 0.717025]
#   label: [0, 1]
#   loss: 0.08007493615150452
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.512316, 0.487684]
#   label: [1, 0]
#   loss: 0.23783616721630096
# ========================================
# Epoch 78 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.082356, 0.917644]
#   label: [0, 1]
#   loss: 0.006782572716474533
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.231939, 0.768061]
#   label: [0, 1]
#   loss: 0.053795650601387024
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.301642, 0.698358]
#   label: [0, 1]
#   loss: 0.09098811447620392
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.537347, 0.462653]
#   label: [1, 0]
#   loss: 0.2140476405620575
# ========================================
# Epoch 79 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.076395, 0.923605]
#   label: [0, 1]
#   loss: 0.0058361985720694065
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.220319, 0.779681]
#   label: [0, 1]
#   loss: 0.04854061082005501
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.288334, 0.711666]
#   label: [0, 1]
#   loss: 0.08313661813735962
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.525885, 0.474115]
#   label: [1, 0]
#   loss: 0.2247852087020874
# ========================================
# Epoch 80 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.077878, 0.922122]
#   label: [0, 1]
#   loss: 0.0060649411752820015
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.227743, 0.772257]
#   label: [0, 1]
#   loss: 0.051866739988327026
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.297516, 0.702484]
#   label: [0, 1]
#   loss: 0.08851548284292221
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.540492, 0.459508]
#   label: [1, 0]
#   loss: 0.21114768087863922
# ========================================
# Epoch 81 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.073865, 0.926135]
#   label: [0, 1]
#   loss: 0.005456014070659876
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.222195, 0.777805]
#   label: [0, 1]
#   loss: 0.049370769411325455
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.288249, 0.711751]
#   label: [0, 1]
#   loss: 0.08308751881122589
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.535608, 0.464392]
#   label: [1, 0]
#   loss: 0.21566034853458405
# ========================================
# Epoch 82 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.077212, 0.922788]
#   label: [0, 1]
#   loss: 0.005961745977401733
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.234746, 0.765254]
#   label: [0, 1]
#   loss: 0.055105648934841156
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.303718, 0.696282]
#   label: [0, 1]
#   loss: 0.09224461019039154
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.557176, 0.442824]
#   label: [1, 0]
#   loss: 0.1960931420326233
# ========================================
# Epoch 83 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.076442, 0.923558]
#   label: [0, 1]
#   loss: 0.005843380466103554
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.236784, 0.763216]
#   label: [0, 1]
#   loss: 0.056066788733005524
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.305703, 0.694297]
#   label: [0, 1]
#   loss: 0.09345453977584839
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.563826, 0.436174]
#   label: [1, 0]
#   loss: 0.19024787843227386
# ========================================
# Epoch 84 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.074710, 0.925290]
#   label: [0, 1]
#   loss: 0.005581531673669815
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.236603, 0.763397]
#   label: [0, 1]
#   loss: 0.055981069803237915
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.304502, 0.695498]
#   label: [0, 1]
#   loss: 0.09272170066833496
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.567487, 0.432513]
#   label: [1, 0]
#   loss: 0.18706771731376648
# ========================================
# Epoch 85 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.074173, 0.925827]
#   label: [0, 1]
#   loss: 0.0055016218684613705
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.240577, 0.759423]
#   label: [0, 1]
#   loss: 0.0578773207962513
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.306303, 0.693697]
#   label: [0, 1]
#   loss: 0.09382176399230957
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.575468, 0.424532]
#   label: [1, 0]
#   loss: 0.180227130651474
# ========================================
# Epoch 86 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.074402, 0.925598]
#   label: [0, 1]
#   loss: 0.005535594187676907
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.245482, 0.754518]
#   label: [0, 1]
#   loss: 0.060261376202106476
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.312159, 0.687841]
#   label: [0, 1]
#   loss: 0.09744329750537872
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.586333, 0.413667]
#   label: [1, 0]
#   loss: 0.1711200773715973
# ========================================
# Epoch 87 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.071285, 0.928715]
#   label: [0, 1]
#   loss: 0.005081553943455219
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.240347, 0.759653]
#   label: [0, 1]
#   loss: 0.05776656046509743
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.306975, 0.693025]
#   label: [0, 1]
#   loss: 0.09423347562551498
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.584848, 0.415152]
#   label: [1, 0]
#   loss: 0.1723514199256897
# ========================================
# Epoch 88 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.074690, 0.925309]
#   label: [0, 1]
#   loss: 0.005578669719398022
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.254169, 0.745831]
#   label: [0, 1]
#   loss: 0.06460176408290863
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.324220, 0.675780]
#   label: [0, 1]
#   loss: 0.10511867702007294
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.607052, 0.392948]
#   label: [1, 0]
#   loss: 0.15440848469734192
# ========================================
# Epoch 89 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.069673, 0.930327]
#   label: [0, 1]
#   loss: 0.004854349419474602
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.242792, 0.757208]
#   label: [0, 1]
#   loss: 0.05894774571061134
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.312311, 0.687689]
#   label: [0, 1]
#   loss: 0.09753838181495667
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.598172, 0.401828]
#   label: [1, 0]
#   loss: 0.1614656001329422
# ========================================
# Epoch 90 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.063065, 0.936935]
#   label: [0, 1]
#   loss: 0.0039772167801856995
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.226108, 0.773892]
#   label: [0, 1]
#   loss: 0.0511249378323555
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.292818, 0.707182]
#   label: [0, 1]
#   loss: 0.08574241399765015
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.581069, 0.418931]
#   label: [1, 0]
#   loss: 0.1755031943321228
# ========================================
# Epoch 91 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.058884, 0.941116]
#   label: [0, 1]
#   loss: 0.0034672822803258896
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.216630, 0.783370]
#   label: [0, 1]
#   loss: 0.04692839831113815
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.281100, 0.718900]
#   label: [0, 1]
#   loss: 0.07901730388402939
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.572431, 0.427569]
#   label: [1, 0]
#   loss: 0.18281510472297668
# ========================================
# Epoch 92 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.057327, 0.942673]
#   label: [0, 1]
#   loss: 0.003286378923803568
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.214661, 0.785339]
#   label: [0, 1]
#   loss: 0.046079348772764206
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.279895, 0.720105]
#   label: [0, 1]
#   loss: 0.07834098488092422
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.574742, 0.425258]
#   label: [1, 0]
#   loss: 0.18084417283535004
# ========================================
# Epoch 93 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.054801, 0.945199]
#   label: [0, 1]
#   loss: 0.0030031506903469563
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.210289, 0.789711]
#   label: [0, 1]
#   loss: 0.04422149062156677
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.273024, 0.726976]
#   label: [0, 1]
#   loss: 0.0745423436164856
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.571805, 0.428195]
#   label: [1, 0]
#   loss: 0.1833505481481552
# ========================================
# Epoch 94 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.052726, 0.947274]
#   label: [0, 1]
#   loss: 0.002780016977339983
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.206587, 0.793413]
#   label: [0, 1]
#   loss: 0.04267800599336624
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.268160, 0.731840]
#   label: [0, 1]
#   loss: 0.07190996408462524
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.570338, 0.429662]
#   label: [1, 0]
#   loss: 0.18460938334465027
# ========================================
# Epoch 95 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.052060, 0.947940]
#   label: [0, 1]
#   loss: 0.0027102548629045486
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.207982, 0.792018]
#   label: [0, 1]
#   loss: 0.04325668886303902
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.269048, 0.730952]
#   label: [0, 1]
#   loss: 0.07238663733005524
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.575942, 0.424058]
#   label: [1, 0]
#   loss: 0.17982491850852966
# ========================================
# Epoch 96 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.053776, 0.946224]
#   label: [0, 1]
#   loss: 0.002891904441639781
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.219427, 0.780573]
#   label: [0, 1]
#   loss: 0.048148367553949356
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.279356, 0.720644]
#   label: [0, 1]
#   loss: 0.07803980261087418
# Validation:   3
# ...
#   Pred: [0.151883, 0.848117]
#   label: [0, 1]
#   loss: 0.023068444803357124
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.165322, 0.834678]
#   label: [0, 1]
#   loss: 0.027331344783306122
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.745371, 0.254629]
#   label: [1, 0]
#   loss: 0.06483576446771622
# ========================================
# Epoch 170 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.009177, 0.990823]
#   label: [0, 1]
#   loss: 8.422283281106502e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.146011, 0.853989]
#   label: [0, 1]
#   loss: 0.021319281309843063
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.158598, 0.841402]
#   label: [0, 1]
#   loss: 0.025153275579214096
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.739650, 0.260350]
#   label: [1, 0]
#   loss: 0.06778236478567123
# ========================================
# Epoch 171 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.009208, 0.990792]
#   label: [0, 1]
#   loss: 8.478261588606983e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.148985, 0.851015]
#   label: [0, 1]
#   loss: 0.022196508944034576
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.161570, 0.838430]
#   label: [0, 1]
#   loss: 0.026104886084794998
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.746571, 0.253429]
#   label: [1, 0]
#   loss: 0.06422601640224457
# ========================================
# Epoch 172 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.009091, 0.990909]
#   label: [0, 1]
#   loss: 8.264149801107123e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.149171, 0.850828]
#   label: [0, 1]
#   loss: 0.022252138704061508
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.161621, 0.838379]
#   label: [0, 1]
#   loss: 0.026121482253074646
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.749363, 0.250637]
#   label: [1, 0]
#   loss: 0.06281878054141998
# ========================================
# Epoch 173 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.008849, 0.991151]
#   label: [0, 1]
#   loss: 7.830735557945445e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.147019, 0.852981]
#   label: [0, 1]
#   loss: 0.021614674478769302
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.159480, 0.840520]
#   label: [0, 1]
#   loss: 0.02543376386165619
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.749237, 0.250763]
#   label: [1, 0]
#   loss: 0.06288190931081772
# ========================================
# Epoch 174 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.008563, 0.991437]
#   label: [0, 1]
#   loss: 7.332520908676088e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.143410, 0.856590]
#   label: [0, 1]
#   loss: 0.020566511899232864
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.156657, 0.843343]
#   label: [0, 1]
#   loss: 0.024541523307561874
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.747462, 0.252538]
#   label: [1, 0]
#   loss: 0.06377563625574112
# ========================================
# Epoch 175 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.008726, 0.991274]
#   label: [0, 1]
#   loss: 7.61502597015351e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.149279, 0.850721]
#   label: [0, 1]
#   loss: 0.02228407748043537
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.161977, 0.838023]
#   label: [0, 1]
#   loss: 0.02623640187084675
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.757788, 0.242212]
#   label: [1, 0]
#   loss: 0.05866668373346329
# ========================================
# Epoch 176 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.008416, 0.991584]
#   label: [0, 1]
#   loss: 7.083376112859696e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.145570, 0.854430]
#   label: [0, 1]
#   loss: 0.02119048312306404
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.157784, 0.842216]
#   label: [0, 1]
#   loss: 0.02489590086042881
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.755011, 0.244989]
#   label: [1, 0]
#   loss: 0.0600196048617363
# ========================================
# Epoch 177 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.008418, 0.991582]
#   label: [0, 1]
#   loss: 7.0869384217076e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.148053, 0.851947]
#   label: [0, 1]
#   loss: 0.021919719874858856
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.159949, 0.840051]
#   label: [0, 1]
#   loss: 0.02558368816971779
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.760662, 0.239339]
#   label: [1, 0]
#   loss: 0.057282909750938416
# ========================================
# Epoch 178 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.008097, 0.991903]
#   label: [0, 1]
#   loss: 6.555517029482871e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.144181, 0.855819]
#   label: [0, 1]
#   loss: 0.02078823558986187
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.155600, 0.844400]
#   label: [0, 1]
#   loss: 0.024211253970861435
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.757974, 0.242026]
#   label: [1, 0]
#   loss: 0.05857657641172409
# ========================================
# Epoch 179 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.008076, 0.991924]
#   label: [0, 1]
#   loss: 6.522779585793614e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.146403, 0.853597]
#   label: [0, 1]
#   loss: 0.021433856338262558
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.156878, 0.843122]
#   label: [0, 1]
#   loss: 0.02461080625653267
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.762779, 0.237221]
#   label: [1, 0]
#   loss: 0.056273724883794785
# ========================================
# Epoch 180 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.007710, 0.992290]
#   label: [0, 1]
#   loss: 5.9437297750264406e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.141171, 0.858829]
#   label: [0, 1]
#   loss: 0.019929200410842896
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.151084, 0.848916]
#   label: [0, 1]
#   loss: 0.022826392203569412
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.757884, 0.242116]
#   label: [1, 0]
#   loss: 0.05862026661634445
# ========================================
# Epoch 181 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.007427, 0.992573]
#   label: [0, 1]
#   loss: 5.5163534852908924e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.137684, 0.862316]
#   label: [0, 1]
#   loss: 0.01895696297287941
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.146650, 0.853350]
#   label: [0, 1]
#   loss: 0.02150612324476242
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.754798, 0.245202]
#   label: [1, 0]
#   loss: 0.060123804956674576
# ========================================
# Epoch 182 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.007353, 0.992647]
#   label: [0, 1]
#   loss: 5.4067619203124195e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.137706, 0.862294]
#   label: [0, 1]
#   loss: 0.01896306872367859
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.147220, 0.852780]
#   label: [0, 1]
#   loss: 0.021673616021871567
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.757504, 0.242496]
#   label: [1, 0]
#   loss: 0.05880448967218399
# ========================================
# Epoch 183 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.007352, 0.992648]
#   label: [0, 1]
#   loss: 5.405744741437957e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.139769, 0.860231]
#   label: [0, 1]
#   loss: 0.019535452127456665
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.149028, 0.850972]
#   label: [0, 1]
#   loss: 0.02220933884382248
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.762475, 0.237525]
#   label: [1, 0]
#   loss: 0.05641801282763481
# ========================================
# Epoch 184 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.007434, 0.992566]
#   label: [0, 1]
#   loss: 5.526639142772183e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.143915, 0.856085]
#   label: [0, 1]
#   loss: 0.020711565390229225
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.152802, 0.847198]
#   label: [0, 1]
#   loss: 0.023348454385995865
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.770213, 0.229787]
#   label: [1, 0]
#   loss: 0.052801892161369324
# ========================================
# Epoch 185 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.007289, 0.992711]
#   label: [0, 1]
#   loss: 5.3131734603084624e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.142764, 0.857236]
#   label: [0, 1]
#   loss: 0.020381471142172813
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.151272, 0.848728]
#   label: [0, 1]
#   loss: 0.022883262485265732
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.770612, 0.229388]
#   label: [1, 0]
#   loss: 0.05261899158358574
# ========================================
# Epoch 186 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.007073, 0.992927]
#   label: [0, 1]
#   loss: 5.002339094062336e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.140046, 0.859954]
#   label: [0, 1]
#   loss: 0.019612951204180717
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.148302, 0.851698]
#   label: [0, 1]
#   loss: 0.021993480622768402
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.769230, 0.230770]
#   label: [1, 0]
#   loss: 0.053254611790180206
# ========================================
# Epoch 187 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006847, 0.993153]
#   label: [0, 1]
#   loss: 4.6883433242328465e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.137346, 0.862654]
#   label: [0, 1]
#   loss: 0.018863869830965996
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.144330, 0.855670]
#   label: [0, 1]
#   loss: 0.020831193774938583
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.766876, 0.233124]
#   label: [1, 0]
#   loss: 0.054346855729818344
# ========================================
# Epoch 188 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006921, 0.993079]
#   label: [0, 1]
#   loss: 4.789661761606112e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.140750, 0.859249]
#   label: [0, 1]
#   loss: 0.01981070451438427
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.148242, 0.851758]
#   label: [0, 1]
#   loss: 0.02197575755417347
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.774025, 0.225975]
#   label: [1, 0]
#   loss: 0.051064711064100266
# ========================================
# Epoch 189 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006726, 0.993274]
#   label: [0, 1]
#   loss: 4.523581810644828e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.137825, 0.862175]
#   label: [0, 1]
#   loss: 0.01899576187133789
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.145631, 0.854369]
#   label: [0, 1]
#   loss: 0.021208472549915314
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.772484, 0.227516]
#   label: [1, 0]
#   loss: 0.051763519644737244
# ========================================
# Epoch 190 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006773, 0.993227]
#   label: [0, 1]
#   loss: 4.5879096433054656e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.141110, 0.858890]
#   label: [0, 1]
#   loss: 0.019912123680114746
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.148524, 0.851476]
#   label: [0, 1]
#   loss: 0.02205936796963215
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.778759, 0.221241]
#   label: [1, 0]
#   loss: 0.04894739016890526
# ========================================
# Epoch 191 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006649, 0.993351]
#   label: [0, 1]
#   loss: 4.4210682972334325e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.140004, 0.859996]
#   label: [0, 1]
#   loss: 0.019601251929998398
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.147889, 0.852111]
#   label: [0, 1]
#   loss: 0.021871116012334824
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.780052, 0.219948]
#   label: [1, 0]
#   loss: 0.04837729036808014
# ========================================
# Epoch 192 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006368, 0.993632]
#   label: [0, 1]
#   loss: 4.0555474697612226e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.134804, 0.865196]
#   label: [0, 1]
#   loss: 0.01817210018634796
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.143398, 0.856602]
#   label: [0, 1]
#   loss: 0.02056301385164261
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.776061, 0.223939]
#   label: [1, 0]
#   loss: 0.05014876276254654
# ========================================
# Epoch 193 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006152, 0.993849]
#   label: [0, 1]
#   loss: 3.784094951697625e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.131997, 0.868003]
#   label: [0, 1]
#   loss: 0.01742332987487316
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.139155, 0.860845]
#   label: [0, 1]
#   loss: 0.01936407759785652
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.773489, 0.226510]
#   label: [1, 0]
#   loss: 0.05130700767040253
# ========================================
# Epoch 194 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.005923, 0.994077]
#   label: [0, 1]
#   loss: 3.508055306156166e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.127769, 0.872231]
#   label: [0, 1]
#   loss: 0.016324950382113457
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.135269, 0.864731]
#   label: [0, 1]
#   loss: 0.018297787755727768
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.769887, 0.230113]
#   label: [1, 0]
#   loss: 0.05295182764530182
# ========================================
# Epoch 195 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006075, 0.993925]
#   label: [0, 1]
#   loss: 3.69037406926509e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.133087, 0.866913]
#   label: [0, 1]
#   loss: 0.017712172120809555
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.141532, 0.858468]
#   label: [0, 1]
#   loss: 0.0200312789529562
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.780169, 0.219831]
#   label: [1, 0]
#   loss: 0.04832570254802704
# ========================================
# Epoch 196 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006057, 0.993943]
#   label: [0, 1]
#   loss: 3.668538556667045e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.134821, 0.865179]
#   label: [0, 1]
#   loss: 0.018176719546318054
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.142581, 0.857419]
#   label: [0, 1]
#   loss: 0.02032933384180069
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.784145, 0.215855]
#   label: [1, 0]
#   loss: 0.04659337177872658
# ========================================
# Epoch 197 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.006012, 0.993988]
#   label: [0, 1]
#   loss: 3.61409256584011e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.135553, 0.864447]
#   label: [0, 1]
#   loss: 0.018374549224972725
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.143042, 0.856958]
#   label: [0, 1]
#   loss: 0.02046089805662632
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.786932, 0.213068]
#   label: [1, 0]
#   loss: 0.045398175716400146
# ========================================
# Epoch 198 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.005861, 0.994139]
#   label: [0, 1]
#   loss: 3.4349206543993205e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.132990, 0.867010]
#   label: [0, 1]
#   loss: 0.017686359584331512
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.140943, 0.859057]
#   label: [0, 1]
#   loss: 0.01986483484506607
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.785817, 0.214183]
#   label: [1, 0]
#   loss: 0.045874468982219696
# ========================================
# Epoch 199 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.005743, 0.994257]
#   label: [0, 1]
#   loss: 3.2984811696223915e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.132020, 0.867980]
#   label: [0, 1]
#   loss: 0.017429294064641
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.139300, 0.860700]
#   label: [0, 1]
#   loss: 0.019404426217079163
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.786231, 0.213769]
#   label: [1, 0]
#   loss: 0.04569719731807709
# ========================================
# Epoch 200 ==============================
# Validation:   0
#   Input: [0, 0]
#   Pred: [0.005639, 0.994361]
#   label: [0, 1]
#   loss: 3.179873965564184e-05
# Validation:   1
#   Input: [0, 1]
#   Pred: [0.130679, 0.869321]
#   label: [0, 1]
#   loss: 0.017076898366212845
# Validation:   2
#   Input: [1, 0]
#   Pred: [0.138433, 0.861567]
#   label: [0, 1]
#   loss: 0.019163575023412704
# Validation:   3
#   Input: [1, 1]
#   Pred: [0.786784, 0.213216]
#   label: [1, 0]
#   loss: 0.04546104371547699
# ========================================
